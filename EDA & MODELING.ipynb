# %% [markdown]
# ## Split data

# %%
data = pd.read_csv('Training Data.csv')

# %%
features = ['Married/Single','Car_Ownership','Profession','CITY','STATE',"House_Ownership"]
label_encoder = LabelEncoder()

for col in features:
    data[col] = label_encoder.fit_transform(data[col])

# %%
X = data.drop(columns=['Risk_Flag', 'Id'])
Y = data['Risk_Flag']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=60, stratify=Y)

# %% [markdown]
# ## Modeling

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
import lightgbm as lgb
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

# %% [markdown]
# ### Logistic Regression

# %%
model_log = LogisticRegression()
model_log.fit(X_train, y_train)
y_pred = model_log.predict(X_test)
acc = accuracy_score(y_pred, y_test)
rec = recall_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Recall: 0.00
# Accuracy: 0.88
# F1 Score: 0.00
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Decision tree

# %%
model_dec = DecisionTreeClassifier()
model_dec.fit(X_train, y_train)
y_pred = model_dec.predict(X_test)
acc = accuracy_score(y_pred, y_test)
rec = recall_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Recall: 0.53
# Accuracy: 0.88
# F1 Score: 0.55

# %% [markdown]
# ### Random Forest

# %%
model_ran = RandomForestClassifier(criterion='gini', bootstrap=True)
model_ran.fit(X_train, y_train)
y_pred = model_ran.predict(X_test)
acc = accuracy_score(y_pred, y_test)
rec = recall_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Recall: 0.61
# Accuracy: 0.90
# F1 Score: 0.57

# %% [markdown]
# ### XgBoost

# %%
model_xgb = XGBClassifier()
model_xgb.fit(X_train, y_train)
y_pred = model_xgb.predict(X_test)
acc = accuracy_score(y_pred, y_test)
rec = recall_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Recall: 0.66
# Accuracy: 0.89
# F1 Score: 0.28

# %% [markdown]
# ### Catboost

# %%
model_cat = CatBoostClassifier()
model_cat.fit(X_train, y_train)
y_pred = model_cat.predict(X_test)
acc = accuracy_score(y_pred, y_test)
rec = recall_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Learning rate set to 0.099301
# 0:	learn: 0.6236500	total: 44.9ms	remaining: 44.8s
# 1:	learn: 0.5695278	total: 82.3ms	remaining: 41s
# 2:	learn: 0.5264845	total: 117ms	remaining: 39s
# 3:	learn: 0.4930481	total: 152ms	remaining: 37.8s
# 4:	learn: 0.4669942	total: 185ms	remaining: 36.8s
# 5:	learn: 0.4464839	total: 217ms	remaining: 36s
# 6:	learn: 0.4304170	total: 253ms	remaining: 35.9s
# 7:	learn: 0.4177355	total: 289ms	remaining: 35.8s
# 8:	learn: 0.4077359	total: 316ms	remaining: 34.8s
# 9:	learn: 0.3995823	total: 348ms	remaining: 34.5s
# 10:	learn: 0.3932903	total: 377ms	remaining: 33.9s
# 11:	learn: 0.3881456	total: 414ms	remaining: 34.1s
# 12:	learn: 0.3837969	total: 450ms	remaining: 34.2s
# 13:	learn: 0.3803433	total: 483ms	remaining: 34s
# 14:	learn: 0.3773780	total: 515ms	remaining: 33.8s
# 15:	learn: 0.3749695	total: 547ms	remaining: 33.6s
# 16:	learn: 0.3730247	total: 579ms	remaining: 33.5s
# 17:	learn: 0.3718006	total: 599ms	remaining: 32.7s
# ...

# %% [markdown]
# ### LightGBM

# %%
model_lgbm = lgb.LGBMClassifier()
model_lgbm.fit(X_train, y_train)
y_pred = model_lgbm.predict(X_test)
acc = accuracy_score(y_pred, y_test)
rec = recall_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Recall: 0.76
# Accuracy: 0.88
# F1 Score: 0.06

# %% [markdown]
# ### KNN

# %%
model_knn = KNeighborsClassifier()
model_knn.fit(X_train, y_train)
y_pred = model_knn.predict(X_test)
acc = accuracy_score(y_pred, y_test)
rec = recall_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Recall: 0.56
# Accuracy: 0.89
# F1 Score: 0.53

# %% [markdown]
# ### Random forest GridSearchCV

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# Define the parameter grid for grid search
param_grid = {'n_estimators': [50, 80, 100, 150],
              'max_depth': [None, 3, 5, 10],
              'min_samples_leaf': [1, 2, 4, 7],
              'min_samples_split': [2, 5, 10, 15]}

# Initialize the RandomForestClassifier
rf = RandomForestClassifier()

# Perform the grid search
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)

# Print the best parameters and the best score
print("Best Parameters: ", grid_search.best_params_)
print("Best Score: ", grid_search.best_score_)

# %%
model_ran = RandomForestClassifier(n_estimators = 80, max_depth = None, min_samples_leaf = 2, min_samples_split = 5)
model_ran.fit(X_train, y_train)
y_pred = model_ran.predict(X_test)
acc = accuracy_score(y_pred, y_test)
rec = recall_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Recall: 0.60
# Accuracy: 0.90
# F1 Score: 0.56

# %% [markdown]
# ### XgBoost GridSearchCV

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {'n_estimators': [300, 350, 390, 400],
              'max_depth': [3, 10, 15, 20],
              'learning_rate': [0.1, 0.01, 0.05, 0.001]
             }

# Initialize the XGBoost classifier
xgb = XGBClassifier()

# Use GridSearchCV to perform the grid search
grid_search = GridSearchCV(xgb, param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)

# Print the best parameters and the best score
print(grid_search.best_params_)
print(grid_search.best_score_)

# %%
model_xgb = XGBClassifier(learning_rate = 0.05, max_depth = 20, n_estimators = 390)
model_xgb.fit(X_train, y_train)
y_pred = model_xgb.predict(X_test)
acc = accuracy_score(y_pred, y_test)
rec = recall_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Recall: 0.59
# Accuracy: 0.90
# F1 Score: 0.56

# %% [markdown]
# ### CatBoost GridSearchCV

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import GridSearchCV

# Create the parameter grid
param_grid = {
    'iterations': [2000, 3000],
    'depth': [4, 5, 7],
    'learning_rate': [0.1, 0.2, 0.3],
    'l2_leaf_reg': [1, 2, 3]
}

# Create the CatBoost model
catboost_model = CatBoostClassifier()

# Create the grid search
grid_search = GridSearchCV(estimator=catboost_model, param_grid=param_grid, cv=3, verbose=2)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)

# Print the best parameters and score
print("Best parameters: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)

# %%
model_cat = CatBoostClassifier(depth = 7, iterations = 3000, l2_leaf_reg = 3, learning_rate = 0.1)
model_cat.fit(X_train, y_train)
y_pred = model_cat.predict(X_test)
acc = accuracy_score(y_pred, y_test)
rec = recall_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc))
print("F1 Score: {:.2f}".format(f1))

# %% [markdown]
# ### Stacking models

# %%
from sklearn.ensemble import StackingClassifier
model1 = CatBoostClassifier(iterations = 3000, depth = 7, learning_rate = 0.05)
model2 = XGBClassifier()
model3 = RandomForestClassifier(criterion='gini', bootstrap=True)


stacking_classifier = StackingClassifier(estimators=[('cb', model1), ('xgb', model2), ('rf', model3)], final_estimator=lgb.LGBMClassifier())

# Fit the stacking classifier on the training data
stacking_classifier.fit(X_train, y_train)

# Make predictions on the test data
y_pred = stacking_classifier.predict(X_test)

# Evaluate the accuracy of the stacking classifier
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)

f1 = f1_score(y_pred, y_test)
print("F1 Score: {:.2f}".format(f1))

rec = recall_score(y_pred, y_test)
print("Recall: {:.2f}".format(rec))
# Out:
# 0:	learn: 0.6568676	total: 31.3ms	remaining: 1m 33s
# 1:	learn: 0.6249600	total: 52ms	remaining: 1m 17s
# 2:	learn: 0.5963366	total: 81.8ms	remaining: 1m 21s
# 3:	learn: 0.5708069	total: 109ms	remaining: 1m 21s
# 4:	learn: 0.5486161	total: 129ms	remaining: 1m 17s
# 5:	learn: 0.5285812	total: 159ms	remaining: 1m 19s
# 6:	learn: 0.5109406	total: 186ms	remaining: 1m 19s
# 7:	learn: 0.4951557	total: 214ms	remaining: 1m 19s
# 8:	learn: 0.4811126	total: 241ms	remaining: 1m 20s
# 9:	learn: 0.4687412	total: 274ms	remaining: 1m 22s
# 10:	learn: 0.4574083	total: 303ms	remaining: 1m 22s
# 11:	learn: 0.4478047	total: 327ms	remaining: 1m 21s
# 12:	learn: 0.4390429	total: 355ms	remaining: 1m 21s
# 13:	learn: 0.4312002	total: 385ms	remaining: 1m 22s
# 14:	learn: 0.4241787	total: 414ms	remaining: 1m 22s
# 15:	learn: 0.4178662	total: 443ms	remaining: 1m 22s
# 16:	learn: 0.4123180	total: 477ms	remaining: 1m 23s
# 17:	learn: 0.4076324	total: 496ms	remaining: 1m 22s
# ...

# %% [markdown]
# ### Undersampling the data

# %%
import random

# %%
data1 = data[data['Risk_Flag'] == 1]
# Y = data['Risk_Flag']
data2 = data[data['Risk_Flag'] == 0]
data0 = data2.iloc[random.sample(range(len(data2)), data1.shape[0])]

# %%
data1.shape[0], data0.shape[0]
# Out:
# (30996, 30996)

# %%
data_undersampling = pd.concat([data0, data1], axis=0); data_undersampling
# Out:
#             Id   Income  Age  Experience  Married/Single  House_Ownership  \
# 96395    96396  1753313   60          17               1                2
# 169903  169904  7517800   76          12               1                1
# 9609      9610  8797493   55          15               1                2
# 88326    88327  6942586   23           6               1                2
# 21880    21881  8776228   37          15               1                2
# ...        ...      ...  ...         ...             ...              ...
# 251973  251974  1244622   35          15               1                2
# 251977  251978  1330613   63          19               1                2
# 251981  251982  1796713   47           2               1                2
# 251982  251983  3182290   52           2               1                2
# 251993  251994  8141027   60          10               1                2
#
#         Car_Ownership  Profession  CITY  STATE  CURRENT_JOB_YRS  \
# ...

# %%
X_under = data_undersampling.drop(columns=['Risk_Flag', 'Id'])
Y_under = data_undersampling['Risk_Flag']

# %%
Xunder_train, Xunder_test, yunder_train, yunder_test = train_test_split(X_under, Y_under, test_size=0.2, random_state=48)

# %% [markdown]
# #### Logistic Regression

# %%
model_log = LogisticRegression()
model_log.fit(Xunder_train, yunder_train)
y_pred = model_log.predict(Xunder_test)
acc = accuracy_score(y_pred, yunder_test)
rec = recall_score(y_pred, yunder_test)
f1 = f1_score(y_pred, yunder_test)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Recall: 0.00
# Accuracy: 0.50
# F1 Score: 0.00
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### Decision Tree

# %%
model_dec = DecisionTreeClassifier(criterion="entropy")
model_dec.fit(Xunder_train, yunder_train)
y_pred = model_dec.predict(Xunder_test)
acc = accuracy_score(y_pred, yunder_test)
rec = recall_score(y_pred, yunder_test)
f1 = f1_score(y_pred, yunder_test)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Recall: 0.85
# Accuracy: 0.86
# F1 Score: 0.87

# %% [markdown]
# #### Random Forest

# %%
model_ran = RandomForestClassifier()
model_ran.fit(Xunder_train, yunder_train)
y_pred = model_ran.predict(Xunder_test)
acc = accuracy_score(y_pred, yunder_test)
rec = recall_score(y_pred, yunder_test)
f1 = f1_score(y_pred, yunder_test)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Recall: 0.88
# Accuracy: 0.85
# F1 Score: 0.84

# %% [markdown]
# #### XgBoost

# %%
model_xgb = XGBClassifier()
model_xgb.fit(Xunder_train, yunder_train)
y_pred = model_xgb.predict(Xunder_test)
acc_dec = accuracy_score(y_pred, yunder_test)
rec = recall_score(y_pred, yunder_test)
f1 = f1_score(y_pred, yunder_test)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc_dec))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Recall: 0.83
# Accuracy: 0.83
# F1 Score: 0.82

# %% [markdown]
# #### CatBoost

# %%
model_cat = CatBoostClassifier()
model_cat.fit(Xunder_train, yunder_train)
y_pred = model_cat.predict(Xunder_test)
acc_dec = accuracy_score(y_pred, yunder_test)
rec = recall_score(y_pred, yunder_test)
f1 = f1_score(y_pred, yunder_test)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc_dec))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Learning rate set to 0.054561
# 0:	learn: 0.6920356	total: 172ms	remaining: 2m 52s
# 1:	learn: 0.6911056	total: 185ms	remaining: 1m 32s
# 2:	learn: 0.6903145	total: 199ms	remaining: 1m 6s
# 3:	learn: 0.6896579	total: 212ms	remaining: 52.8s
# 4:	learn: 0.6889120	total: 225ms	remaining: 44.7s
# 5:	learn: 0.6880266	total: 235ms	remaining: 38.9s
# 6:	learn: 0.6873343	total: 245ms	remaining: 34.8s
# 7:	learn: 0.6866995	total: 255ms	remaining: 31.6s
# 8:	learn: 0.6858639	total: 264ms	remaining: 29.1s
# 9:	learn: 0.6851336	total: 274ms	remaining: 27.1s
# 10:	learn: 0.6845122	total: 284ms	remaining: 25.5s
# 11:	learn: 0.6838288	total: 293ms	remaining: 24.2s
# 12:	learn: 0.6831534	total: 303ms	remaining: 23s
# 13:	learn: 0.6823757	total: 312ms	remaining: 22s
# 14:	learn: 0.6817578	total: 322ms	remaining: 21.2s
# 15:	learn: 0.6810781	total: 332ms	remaining: 20.4s
# 16:	learn: 0.6804433	total: 342ms	remaining: 19.8s
# 17:	learn: 0.6799364	total: 353ms	remaining: 19.3s
# ...

# %% [markdown]
# #### LightGBM

# %%
model_lgbm = lgb.LGBMClassifier()
model_lgbm.fit(Xunder_train, yunder_train)
y_pred = model_lgbm.predict(Xunder_test)
acc_dec = accuracy_score(y_pred, yunder_test)
rec = recall_score(y_pred, yunder_test)
f1 = f1_score(y_pred, yunder_test)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc_dec))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Recall: 0.79
# Accuracy: 0.78
# F1 Score: 0.78

# %% [markdown]
# #### KNN

# %%
model_knn = KNeighborsClassifier()
model_knn.fit(Xunder_train, yunder_train)
y_pred = model_knn.predict(Xunder_test)
acc_dec = accuracy_score(y_pred, yunder_test)
rec = recall_score(y_pred, yunder_test)
f1 = f1_score(y_pred, yunder_test)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc_dec))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Recall: 0.84
# Accuracy: 0.84
# F1 Score: 0.83

# %%
from sklearn.ensemble import StackingClassifier
model1 = CatBoostClassifier(iterations = 3000, depth = 7, learning_rate = 0.05)
model2 = XGBClassifier()
model3 = RandomForestClassifier(criterion='gini', bootstrap=True)


stacking_classifier = StackingClassifier(estimators=[('cb', model1), ('xgb', model2), ('rf', model3)], final_estimator=lgb.LGBMClassifier())

# Fit the stacking classifier on the training data
stacking_classifier.fit(Xunder_train, yunder_train)

# Make predictions on the test data
y_pred = stacking_classifier.predict(Xunder_test)

# Evaluate the accuracy of the stacking classifier
accuracy = accuracy_score(yunder_test, y_pred)
print("Accuracy: ", accuracy)

f1 = f1_score(y_pred, yunder_test)
print("F1 Score: {:.2f}".format(f1))

rec = recall_score(y_pred, yunder_test)
print("Recall: {:.2f}".format(rec))
# Out:
# 0:	learn: 0.6917637	total: 184ms	remaining: 9m 11s
# 1:	learn: 0.6907321	total: 203ms	remaining: 5m 4s
# 2:	learn: 0.6894270	total: 221ms	remaining: 3m 40s
# 3:	learn: 0.6880951	total: 239ms	remaining: 2m 59s
# 4:	learn: 0.6871020	total: 257ms	remaining: 2m 34s
# 5:	learn: 0.6860336	total: 275ms	remaining: 2m 17s
# 6:	learn: 0.6850688	total: 292ms	remaining: 2m 4s
# 7:	learn: 0.6839531	total: 310ms	remaining: 1m 55s
# 8:	learn: 0.6826533	total: 328ms	remaining: 1m 48s
# 9:	learn: 0.6817491	total: 346ms	remaining: 1m 43s
# 10:	learn: 0.6806927	total: 364ms	remaining: 1m 38s
# 11:	learn: 0.6797361	total: 382ms	remaining: 1m 35s
# 12:	learn: 0.6790110	total: 403ms	remaining: 1m 32s
# 13:	learn: 0.6781184	total: 421ms	remaining: 1m 29s
# 14:	learn: 0.6773709	total: 438ms	remaining: 1m 27s
# 15:	learn: 0.6763026	total: 456ms	remaining: 1m 25s
# 16:	learn: 0.6754826	total: 473ms	remaining: 1m 23s
# 17:	learn: 0.6747250	total: 490ms	remaining: 1m 21s
# ...

# %%
y_pred = model_dec.predict(X)
acc_dec = accuracy_score(y_pred, Y)
rec = recall_score(y_pred, Y)
f1 = f1_score(y_pred, Y)
print("Recall: {:.2f}".format(rec))
print("Accuracy: {:.2f}".format(acc_dec))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Recall: 0.49
# Accuracy: 0.87
# F1 Score: 0.65
